# %%
from bing_image_downloader import downloader
import os

downloader.download('bavaria license plate with car', limit=100, output_dir=os.path.join(os.getcwd(), 'images'))
# Out:
# [%] Downloading Images to c:\DISK (D)\DOWNLOADS\New folder\images\bavaria license plate with car
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.pinimg.com/736x/96/4e/b6/964eb635ef30a02ff46cc05e3be7600b--bavaria-coat-of-arms.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.ebayimg.com/images/g/tHwAAOSwpz9eUDoL/s-l640.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.customeuropeanplates.com/images/bayern.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.pinimg.com/originals/db/fd/28/dbfd2854e8a17c3b95e26d66b6934e8a.png
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i.pinimg.com/originals/23/29/ca/2329cac8e064c7850ae23d0f217f2223.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://i.ebayimg.com/images/g/Z2QAAOSw-mdbdYjt/s-l640.jpg
# [%] File Downloaded !
#
# ...
